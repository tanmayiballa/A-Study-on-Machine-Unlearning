# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
'''for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))'''

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# "for dirname, _, filenames in os.walk('/kaggle/input'):\n    for filename in filenames:\n        print(os.path.join(dirname, filename))"

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow_addons as tfa
#from keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D


print("TensorFlow Version:", tf.__version__)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# TensorFlow Version: 2.13.0

# %%
base_dir = "/kaggle/input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['NonDemented', 'ModerateDemented', 'MildDemented', 'VeryMildDemented']

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
#Performing Image Augmentation to have more data samples

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    labels =dict(zip([0,1,2,3], CLASSES))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)

# %%
train_data, train_labels = train_data_gen.next()

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (6400, 176, 176, 3) (6400, 4)

# %%
#Performing over-sampling of the data, since the classes are imbalanced

sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (12800, 176, 176, 3) (12800, 4)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
inception_model = InceptionV3(input_shape=(176, 176, 3), include_top=False, weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
for layer in inception_model.layers:
    layer.trainable=False

# %%
custom_inception_model = Sequential([
        inception_model,
        Dropout(0.5),
        GlobalAveragePooling2D(),
        Flatten(),
        BatchNormalization(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        BatchNormalization(),
        Dense(4, activation='softmax')        
    ], name = "inception_cnn_model")

# %%
class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('acc') > 0.99:
            print("\nReached accuracy threshold! Terminating training.")
            self.model.stop_training = True
            
my_callback = MyCallback()

#ReduceLROnPlateau to stabilize the training process of the model
rop_callback = ReduceLROnPlateau(monitor="val_loss", patience=3)

# %%
METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc'),
           tf.keras.metrics.AUC(name='auc'),
           tfa.metrics.F1Score(num_classes=4)]

CALLBACKS = [my_callback, rop_callback]
    
custom_inception_model.compile(optimizer='rmsprop',
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=METRICS)

custom_inception_model.summary()
# Out:
# Model: "inception_cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 4, 4, 2048)        21802784
#
#  dropout (Dropout)           (None, 4, 4, 2048)        0
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  batch_normalization_94 (Ba  (None, 2048)              8192
#  tchNormalization)
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_95 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_96 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_97 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  batch_normalization_98 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 23036644 (87.88 MB)
# Trainable params: 1227844 (4.68 MB)
# Non-trainable params: 21808800 (83.19 MB)
# _________________________________________________________________

# %%
#Fit the training data to the model and validate it using the validation data
EPOCHS = 100
with tf.device('/device:GPU:0'):
    history = custom_inception_model.fit(train_data, train_labels, validation_data=(val_data, val_labels), callbacks=CALLBACKS, epochs=EPOCHS)
# Out:
# Epoch 1/100
# 2023-12-08 22:00:22.084847: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape ininception_cnn_model/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 256/256 [==============================] - 34s 73ms/step - loss: 1.3793 - acc: 0.4077 - auc: 0.6806 - f1_score: 0.4016 - val_loss: 0.7924 - val_acc: 0.6353 - val_auc: 0.8842 - val_f1_score: 0.6157 - lr: 0.0010
# Epoch 2/100
# 256/256 [==============================] - 15s 58ms/step - loss: 0.9232 - acc: 0.5734 - auc: 0.8435 - f1_score: 0.5648 - val_loss: 0.6630 - val_acc: 0.6841 - val_auc: 0.9168 - val_f1_score: 0.6671 - lr: 0.0010
# Epoch 3/100
# 256/256 [==============================] - 15s 59ms/step - loss: 0.7834 - acc: 0.6428 - auc: 0.8877 - f1_score: 0.6356 - val_loss: 0.5921 - val_acc: 0.7339 - val_auc: 0.9362 - val_f1_score: 0.7305 - lr: 0.0010
100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2492 - acc: 0.9097 - auc: 0.9879 - f1_score: 0.9095 - val_loss: 0.2781 - val_acc: 0.8872 - val_auc: 0.9858 - val_f1_score: 0.8861 - lr: 1.0000e-04
# Epoch 32/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2404 - acc: 0.9176 - auc: 0.9885 - f1_score: 0.9174 - val_loss: 0.2763 - val_acc: 0.8848 - val_auc: 0.9861 - val_f1_score: 0.8835 - lr: 1.0000e-04
# Epoch 33/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2427 - acc: 0.9152 - auc: 0.9882 - f1_score: 0.9152 - val_loss: 0.2747 - val_acc: 0.8911 - val_auc: 0.9864 - val_f1_score: 0.8901 - lr: 1.0000e-04
# Epoch 34/100
# 256/256 [==============================] - 15s 61ms/step - loss: 0.2180 - acc: 0.9213 - auc: 0.9906 - f1_score: 0.9211 - val_loss: 0.2709 - val_acc: 0.8926 - val_auc: 0.9867 - val_f1_score: 0.8914 - lr: 1.0000e-04
# Epoch 35/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2343 - acc: 0.9211 - auc: 0.9886 - f1_score: 0.9211 - val_loss: 0.2729 - val_acc: 0.8940 - val_auc: 0.9868 - val_f1_score: 0.8928 - lr: 1.0000e-04
# Epoch 36/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2262 - acc: 0.9233 - auc: 0.9894 - f1_score: 0.9233 - val_loss: 0.2693 - val_acc: 0.8936 - val_auc: 0.9870 - val_f1_score: 0.8926 - lr: 1.0000e-04
# Epoch 37/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2351 - acc: 0.9185 - auc: 0.9886 - f1_score: 0.9184 - val_loss: 0.2703 - val_acc: 0.8955 - val_auc: 0.9869 - val_f1_score: 0.8943 - lr: 1.0000e-04
# Epoch 38/100
# 256/256 [==============================] - 15s 61ms/step - loss: 0.2160 - acc: 0.9280 - auc: 0.9904 - f1_score: 0.9277 - val_loss: 0.2696 - val_acc: 0.8994 - val_auc: 0.9868 - val_f1_score: 0.8983 - lr: 1.0000e-04
# Epoch 39/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2075 - acc: 0.9285 - auc: 0.9914 - f1_score: 0.9284 - val_loss: 0.2631 - val_acc: 0.8999 - val_auc: 0.9873 - val_f1_score: 0.8989 - lr: 1.0000e-04
# Epoch 40/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2091 - acc: 0.9312 - auc: 0.9910 - f1_score: 0.9309 - val_loss: 0.2642 - val_acc: 0.8989 - val_auc: 0.9875 - val_f1_score: 0.8979 - lr: 1.0000e-04
# Epoch 41/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2043 - acc: 0.9307 - auc: 0.9911 - f1_score: 0.9305 - val_loss: 0.2664 - val_acc: 0.8989 - val_auc: 0.9872 - val_f1_score: 0.8978 - lr: 1.0000e-04
# Epoch 42/100
# 256/256 [==============================] - 15s 60ms/step - loss: 0.2119 - acc: 0.9301 - auc: 0.9904 - f1_score: 0.9299 - val_loss: 0.2666 - val_acc: 0.9009 - val_auc: 0.9873 - val_f1_score: 0.8996 - lr: 1.0000e-04
# Epoch 43/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2045 - acc: 0.9341 - auc: 0.9905 - f1_score: 0.9340 - val_loss: 0.2637 - val_acc: 0.8989 - val_auc: 0.9873 - val_f1_score: 0.8980 - lr: 1.0000e-05
# Epoch 44/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2161 - acc: 0.9266 - auc: 0.9903 - f1_score: 0.9266 - val_loss: 0.2632 - val_acc: 0.9019 - val_auc: 0.9873 - val_f1_score: 0.9008 - lr: 1.0000e-05
# Epoch 45/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1951 - acc: 0.9347 - auc: 0.9920 - f1_score: 0.9345 - val_loss: 0.2647 - val_acc: 0.9014 - val_auc: 0.9873 - val_f1_score: 0.9003 - lr: 1.0000e-05
# Epoch 46/100
# 256/256 [==============================] - 15s 61ms/step - loss: 0.2210 - acc: 0.9249 - auc: 0.9896 - f1_score: 0.9249 - val_loss: 0.2630 - val_acc: 0.9023 - val_auc: 0.9874 - val_f1_score: 0.9013 - lr: 1.0000e-06
# Epoch 47/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2088 - acc: 0.9305 - auc: 0.9908 - f1_score: 0.9303 - val_loss: 0.2646 - val_acc: 0.8994 - val_auc: 0.9873 - val_f1_score: 0.8984 - lr: 1.0000e-06
# Epoch 48/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2075 - acc: 0.9282 - auc: 0.9911 - f1_score: 0.9281 - val_loss: 0.2660 - val_acc: 0.8999 - val_auc: 0.9872 - val_f1_score: 0.8988 - lr: 1.0000e-06
# Epoch 49/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1935 - acc: 0.9342 - auc: 0.9921 - f1_score: 0.9341 - val_loss: 0.2653 - val_acc: 0.8994 - val_auc: 0.9874 - val_f1_score: 0.8983 - lr: 1.0000e-07
# Epoch 50/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2000 - acc: 0.9308 - auc: 0.9918 - f1_score: 0.9307 - val_loss: 0.2632 - val_acc: 0.9014 - val_auc: 0.9875 - val_f1_score: 0.9003 - lr: 1.0000e-07
# Epoch 51/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1947 - acc: 0.9323 - auc: 0.9923 - f1_score: 0.9321 - val_loss: 0.2616 - val_acc: 0.9009 - val_auc: 0.9877 - val_f1_score: 0.8999 - lr: 1.0000e-07
# Epoch 52/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2003 - acc: 0.9323 - auc: 0.9917 - f1_score: 0.9320 - val_loss: 0.2629 - val_acc: 0.9009 - val_auc: 0.9876 - val_f1_score: 0.8998 - lr: 1.0000e-07
# Epoch 53/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1961 - acc: 0.9315 - auc: 0.9921 - f1_score: 0.9314 - val_loss: 0.2633 - val_acc: 0.8999 - val_auc: 0.9875 - val_f1_score: 0.8987 - lr: 1.0000e-07
# Epoch 54/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1922 - acc: 0.9338 - auc: 0.9921 - f1_score: 0.9337 - val_loss: 0.2643 - val_acc: 0.8994 - val_auc: 0.9875 - val_f1_score: 0.8983 - lr: 1.0000e-07
# Epoch 55/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2006 - acc: 0.9309 - auc: 0.9919 - f1_score: 0.9308 - val_loss: 0.2651 - val_acc: 0.8979 - val_auc: 0.9873 - val_f1_score: 0.8968 - lr: 1.0000e-08
# Epoch 56/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2086 - acc: 0.9292 - auc: 0.9908 - f1_score: 0.9292 - val_loss: 0.2626 - val_acc: 0.8999 - val_auc: 0.9874 - val_f1_score: 0.8989 - lr: 1.0000e-08
# Epoch 57/100
# 256/256 [==============================] - 15s 61ms/step - loss: 0.1994 - acc: 0.9312 - auc: 0.9914 - f1_score: 0.9310 - val_loss: 0.2650 - val_acc: 0.9009 - val_auc: 0.9872 - val_f1_score: 0.8999 - lr: 1.0000e-08
# Epoch 58/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1993 - acc: 0.9313 - auc: 0.9916 - f1_score: 0.9311 - val_loss: 0.2635 - val_acc: 0.9014 - val_auc: 0.9875 - val_f1_score: 0.9003 - lr: 1.0000e-09
# Epoch 59/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1950 - acc: 0.9335 - auc: 0.9923 - f1_score: 0.9333 - val_loss: 0.2626 - val_acc: 0.9019 - val_auc: 0.9876 - val_f1_score: 0.9007 - lr: 1.0000e-09
# Epoch 60/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1963 - acc: 0.9310 - auc: 0.9922 - f1_score: 0.9309 - val_loss: 0.2634 - val_acc: 0.9009 - val_auc: 0.9875 - val_f1_score: 0.8998 - lr: 1.0000e-09
# Epoch 61/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2028 - acc: 0.9277 - auc: 0.9918 - f1_score: 0.9276 - val_loss: 0.2643 - val_acc: 0.8994 - val_auc: 0.9872 - val_f1_score: 0.8983 - lr: 1.0000e-10
# Epoch 62/100
# 256/256 [==============================] - 15s 61ms/step - loss: 0.1965 - acc: 0.9348 - auc: 0.9918 - f1_score: 0.9347 - val_loss: 0.2623 - val_acc: 0.9009 - val_auc: 0.9876 - val_f1_score: 0.8998 - lr: 1.0000e-10
# Epoch 63/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2023 - acc: 0.9303 - auc: 0.9914 - f1_score: 0.9302 - val_loss: 0.2641 - val_acc: 0.9014 - val_auc: 0.9875 - val_f1_score: 0.9002 - lr: 1.0000e-10
# Epoch 64/100
# 256/256 [==============================] - 15s 61ms/step - loss: 0.2126 - acc: 0.9271 - auc: 0.9907 - f1_score: 0.9270 - val_loss: 0.2662 - val_acc: 0.9009 - val_auc: 0.9873 - val_f1_score: 0.8997 - lr: 1.0000e-11
# Epoch 65/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2050 - acc: 0.9320 - auc: 0.9911 - f1_score: 0.9320 - val_loss: 0.2663 - val_acc: 0.9014 - val_auc: 0.9874 - val_f1_score: 0.9002 - lr: 1.0000e-11
# Epoch 66/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1914 - acc: 0.9336 - auc: 0.9922 - f1_score: 0.9334 - val_loss: 0.2629 - val_acc: 0.8999 - val_auc: 0.9874 - val_f1_score: 0.8989 - lr: 1.0000e-11
# Epoch 67/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1936 - acc: 0.9354 - auc: 0.9923 - f1_score: 0.9353 - val_loss: 0.2641 - val_acc: 0.9023 - val_auc: 0.9875 - val_f1_score: 0.9011 - lr: 1.0000e-12
# Epoch 68/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2030 - acc: 0.9291 - auc: 0.9916 - f1_score: 0.9289 - val_loss: 0.2657 - val_acc: 0.8984 - val_auc: 0.9873 - val_f1_score: 0.8971 - lr: 1.0000e-12
# Epoch 69/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1905 - acc: 0.9387 - auc: 0.9919 - f1_score: 0.9386 - val_loss: 0.2632 - val_acc: 0.9004 - val_auc: 0.9874 - val_f1_score: 0.8993 - lr: 1.0000e-12
# Epoch 70/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1862 - acc: 0.9351 - auc: 0.9928 - f1_score: 0.9349 - val_loss: 0.2657 - val_acc: 0.8999 - val_auc: 0.9874 - val_f1_score: 0.8988 - lr: 1.0000e-13
# Epoch 71/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2076 - acc: 0.9303 - auc: 0.9910 - f1_score: 0.9302 - val_loss: 0.2628 - val_acc: 0.9019 - val_auc: 0.9875 - val_f1_score: 0.9008 - lr: 1.0000e-13
# Epoch 72/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1944 - acc: 0.9358 - auc: 0.9918 - f1_score: 0.9357 - val_loss: 0.2641 - val_acc: 0.8989 - val_auc: 0.9872 - val_f1_score: 0.8978 - lr: 1.0000e-13
# Epoch 73/100
# 256/256 [==============================] - 15s 61ms/step - loss: 0.2000 - acc: 0.9321 - auc: 0.9914 - f1_score: 0.9320 - val_loss: 0.2631 - val_acc: 0.9023 - val_auc: 0.9873 - val_f1_score: 0.9013 - lr: 1.0000e-14
# Epoch 74/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1824 - acc: 0.9380 - auc: 0.9931 - f1_score: 0.9378 - val_loss: 0.2633 - val_acc: 0.9009 - val_auc: 0.9876 - val_f1_score: 0.8998 - lr: 1.0000e-14
# Epoch 75/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2095 - acc: 0.9268 - auc: 0.9908 - f1_score: 0.9266 - val_loss: 0.2632 - val_acc: 0.9014 - val_auc: 0.9876 - val_f1_score: 0.9003 - lr: 1.0000e-14
# Epoch 76/100
# 256/256 [==============================] - 15s 61ms/step - loss: 0.2058 - acc: 0.9288 - auc: 0.9913 - f1_score: 0.9287 - val_loss: 0.2619 - val_acc: 0.9023 - val_auc: 0.9876 - val_f1_score: 0.9013 - lr: 1.0000e-15
# Epoch 77/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2095 - acc: 0.9281 - auc: 0.9911 - f1_score: 0.9280 - val_loss: 0.2654 - val_acc: 0.9014 - val_auc: 0.9874 - val_f1_score: 0.9002 - lr: 1.0000e-15
# Epoch 78/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2042 - acc: 0.9304 - auc: 0.9911 - f1_score: 0.9303 - val_loss: 0.2634 - val_acc: 0.9004 - val_auc: 0.9875 - val_f1_score: 0.8992 - lr: 1.0000e-15
# Epoch 79/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2061 - acc: 0.9297 - auc: 0.9911 - f1_score: 0.9294 - val_loss: 0.2621 - val_acc: 0.9009 - val_auc: 0.9876 - val_f1_score: 0.8998 - lr: 1.0000e-16
# Epoch 80/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2107 - acc: 0.9290 - auc: 0.9905 - f1_score: 0.9288 - val_loss: 0.2645 - val_acc: 0.8989 - val_auc: 0.9873 - val_f1_score: 0.8978 - lr: 1.0000e-16
# Epoch 81/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2069 - acc: 0.9297 - auc: 0.9911 - f1_score: 0.9296 - val_loss: 0.2631 - val_acc: 0.9004 - val_auc: 0.9875 - val_f1_score: 0.8994 - lr: 1.0000e-16
# Epoch 82/100
# 256/256 [==============================] - 15s 61ms/step - loss: 0.1957 - acc: 0.9326 - auc: 0.9921 - f1_score: 0.9325 - val_loss: 0.2670 - val_acc: 0.8994 - val_auc: 0.9873 - val_f1_score: 0.8981 - lr: 1.0000e-17
# Epoch 83/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1972 - acc: 0.9337 - auc: 0.9919 - f1_score: 0.9337 - val_loss: 0.2666 - val_acc: 0.8984 - val_auc: 0.9873 - val_f1_score: 0.8971 - lr: 1.0000e-17
# Epoch 84/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2060 - acc: 0.9303 - auc: 0.9912 - f1_score: 0.9302 - val_loss: 0.2649 - val_acc: 0.9009 - val_auc: 0.9873 - val_f1_score: 0.8998 - lr: 1.0000e-17
# Epoch 85/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1983 - acc: 0.9354 - auc: 0.9915 - f1_score: 0.9353 - val_loss: 0.2647 - val_acc: 0.8989 - val_auc: 0.9875 - val_f1_score: 0.8978 - lr: 1.0000e-18
# Epoch 86/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1930 - acc: 0.9331 - auc: 0.9922 - f1_score: 0.9330 - val_loss: 0.2651 - val_acc: 0.8999 - val_auc: 0.9870 - val_f1_score: 0.8988 - lr: 1.0000e-18
# Epoch 87/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2006 - acc: 0.9329 - auc: 0.9913 - f1_score: 0.9327 - val_loss: 0.2671 - val_acc: 0.8979 - val_auc: 0.9873 - val_f1_score: 0.8966 - lr: 1.0000e-18
# Epoch 88/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1973 - acc: 0.9318 - auc: 0.9921 - f1_score: 0.9317 - val_loss: 0.2650 - val_acc: 0.8984 - val_auc: 0.9874 - val_f1_score: 0.8972 - lr: 1.0000e-19
# Epoch 89/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2002 - acc: 0.9327 - auc: 0.9914 - f1_score: 0.9325 - val_loss: 0.2648 - val_acc: 0.9004 - val_auc: 0.9874 - val_f1_score: 0.8993 - lr: 1.0000e-19
# Epoch 90/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2087 - acc: 0.9265 - auc: 0.9910 - f1_score: 0.9263 - val_loss: 0.2628 - val_acc: 0.8999 - val_auc: 0.9874 - val_f1_score: 0.8989 - lr: 1.0000e-19
# Epoch 91/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2022 - acc: 0.9314 - auc: 0.9913 - f1_score: 0.9312 - val_loss: 0.2640 - val_acc: 0.9009 - val_auc: 0.9875 - val_f1_score: 0.8998 - lr: 1.0000e-20
# Epoch 92/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2101 - acc: 0.9292 - auc: 0.9907 - f1_score: 0.9291 - val_loss: 0.2646 - val_acc: 0.8999 - val_auc: 0.9875 - val_f1_score: 0.8988 - lr: 1.0000e-20
# Epoch 93/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2043 - acc: 0.9277 - auc: 0.9916 - f1_score: 0.9276 - val_loss: 0.2656 - val_acc: 0.8989 - val_auc: 0.9874 - val_f1_score: 0.8978 - lr: 1.0000e-20
# Epoch 94/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2114 - acc: 0.9274 - auc: 0.9907 - f1_score: 0.9273 - val_loss: 0.2643 - val_acc: 0.9009 - val_auc: 0.9875 - val_f1_score: 0.8998 - lr: 1.0000e-21
# Epoch 95/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1941 - acc: 0.9314 - auc: 0.9920 - f1_score: 0.9313 - val_loss: 0.2631 - val_acc: 0.9014 - val_auc: 0.9876 - val_f1_score: 0.9003 - lr: 1.0000e-21
# Epoch 96/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2003 - acc: 0.9303 - auc: 0.9914 - f1_score: 0.9301 - val_loss: 0.2635 - val_acc: 0.9019 - val_auc: 0.9874 - val_f1_score: 0.9007 - lr: 1.0000e-21
# Epoch 97/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2028 - acc: 0.9321 - auc: 0.9913 - f1_score: 0.9320 - val_loss: 0.2634 - val_acc: 0.9019 - val_auc: 0.9873 - val_f1_score: 0.9007 - lr: 1.0000e-22
# Epoch 98/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2020 - acc: 0.9297 - auc: 0.9914 - f1_score: 0.9296 - val_loss: 0.2649 - val_acc: 0.9014 - val_auc: 0.9875 - val_f1_score: 0.9002 - lr: 1.0000e-22
# Epoch 99/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.2032 - acc: 0.9344 - auc: 0.9909 - f1_score: 0.9344 - val_loss: 0.2652 - val_acc: 0.8999 - val_auc: 0.9874 - val_f1_score: 0.8988 - lr: 1.0000e-22
# Epoch 100/100
# 256/256 [==============================] - 16s 61ms/step - loss: 0.1963 - acc: 0.9327 - auc: 0.9919 - f1_score: 0.9326 - val_loss: 0.2652 - val_acc: 0.8984 - val_auc: 0.9874 - val_f1_score: 0.8972 - lr: 1.0000e-23

# %%
test_scores = custom_inception_model.evaluate(test_data, test_labels)
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 80/80 [==============================] - 4s 45ms/step - loss: 0.2969 - acc: 0.8863 - auc: 0.9848 - f1_score: 0.8863
# Testing Accuracy: 88.63%
